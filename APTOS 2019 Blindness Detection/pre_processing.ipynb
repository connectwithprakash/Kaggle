# %%
# comment this line if using local machine
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# install kaggle api
# !pip install kaggle

# %%
# download kaggle api and save to .kaggle dir
from googleapiclient.discovery import build
import io, os
from googleapiclient.http import MediaIoBaseDownload
from google.colab import auth
auth.authenticate_user()
drive_service = build('drive', 'v3')
results = drive_service.files().list(
        q="name = 'kaggle.json'", fields="files(id)").execute()
kaggle_api_key = results.get('files', [])
filename = "/root/.kaggle/kaggle.json"  # NOTE: This is different from the Medium post!
os.makedirs(os.path.dirname(filename), exist_ok=True)
request = drive_service.files().get_media(fileId=kaggle_api_key[0]['id'])
fh = io.FileIO(filename, 'wb')
downloader = MediaIoBaseDownload(fh, request)
done = False
while done is False:
    status, done = downloader.next_chunk()
    print("Download %d%%." % int(status.progress() * 100))
os.chmod(filename, 600)

# %%
# lists all the competition status
# !kaggle competitions list
# Out:
# ref                                            deadline             category            reward  teamCount  userHasEntered
# ---------------------------------------------  -------------------  ---------------  ---------  ---------  --------------
# digit-recognizer                               2030-01-01 00:00:00  Getting Started  Knowledge       2935           False
# titanic                                        2030-01-01 00:00:00  Getting Started  Knowledge      11487           False
# house-prices-advanced-regression-techniques    2030-01-01 00:00:00  Getting Started  Knowledge       4252           False
# imagenet-object-localization-challenge         2029-12-31 07:00:00  Research         Knowledge         49           False
# competitive-data-science-predict-future-sales  2019-12-31 23:59:00  Playground           Kudos       3863           False
# severstal-steel-defect-detection               2019-10-24 23:59:00  Featured          $120,000        485           False
# ...

# %%
# download cometiton dataset
# !kaggle competitions download -c aptos2019-blindness-detection
# Out:
# ...
# 100% 8.00G/8.01G [01:03<00:00, 127MB/s]
# 100% 8.01G/8.01G [01:03<00:00, 136MB/s]
# ...
# 100% 1.50G/1.50G [00:10<00:00, 172MB/s]
# 100% 1.50G/1.50G [00:10<00:00, 151MB/s]
# ...
#   0% 0.00/53.7k [00:00<?, ?B/s]
# 100% 53.7k/53.7k [00:00<00:00, 56.5MB/s]
# ...
#   0% 0.00/24.5k [00:00<?, ?B/s]
# 100% 24.5k/24.5k [00:00<00:00, 25.6MB/s]
# ...
#   0% 0.00/28.3k [00:00<?, ?B/s]
# 100% 28.3k/28.3k [00:00<00:00, 29.1MB/s]

# %%
# move all the downloaded files from dcontent dir to custom dir
# !mv sample_submission.csv, test.csv train.csv test_images.zip train_images.zip "drive/My Drive/Colab Notebooks/Kaggle"
# Out:
# mv: invalid option -- 'd'
# Try 'mv --help' for more information.

# %%
# !unzip drive/My\ Drive/Colab\ Notebooks/Kaggle/Dataset/train_images.zip -d drive/My\ Drive/Colab\ Notebooks/Kaggle/Dataset/train
# Out:
# Archive:  drive/My Drive/Colab Notebooks/Kaggle/Dataset/train_images.zip
#   inflating: drive/My Drive/Colab Notebooks/Kaggle/Dataset/train/7b9d519cbd66.png
#   inflating: drive/My Drive/Colab Notebooks/Kaggle/Dataset/train/ae49cc60f251.png
#   inflating: drive/My Drive/Colab Notebooks/Kaggle/Dataset/train/b294927b14b0.png
#   inflating: drive/My Drive/Colab Notebooks/Kaggle/Dataset/train/f4d3777f2710.png
#   inflating: drive/My Drive/Colab Notebooks/Kaggle/Dataset/train/d74ccc796517.png
#   inflating: drive/My Drive/Colab Notebooks/Kaggle/Dataset/train/15bed5adde74.png
#   inflating: drive/My Drive/Colab Notebooks/Kaggle/Dataset/train/f002ce614c59.png
#   inflating: drive/My Drive/Colab Notebooks/Kaggle/Dataset/train/7335a2d43ada.png
#   inflating: drive/My Drive/Colab Notebooks/Kaggle/Dataset/train/9b7b6e4db1d5.png
#   inflating: drive/My Drive/Colab Notebooks/Kaggle/Dataset/train/1968183f0e61.png
#   inflating: drive/My Drive/Colab Notebooks/Kaggle/Dataset/train/d91273efb92a.png
# ...

# %%
# !find drive/My\ Drive/Colab\ Notebooks/Kaggle/Dataset/train -type f | wc -l
# Out:
# 3662

# %%
# !unzip drive/My\ Drive/Colab\ Notebooks/Kaggle/Dataset/test_images.zip -d drive/My\ Drive/Colab\ Notebooks/Kaggle/Dataset/test
# Out:
# Archive:  drive/My Drive/Colab Notebooks/Kaggle/Dataset/test_images.zip
#   inflating: drive/My Drive/Colab Notebooks/Kaggle/Dataset/test/270a532df702.png
#   inflating: drive/My Drive/Colab Notebooks/Kaggle/Dataset/test/86fd5df366b2.png
#   inflating: drive/My Drive/Colab Notebooks/Kaggle/Dataset/test/72dd7ca97f55.png
#   inflating: drive/My Drive/Colab Notebooks/Kaggle/Dataset/test/ec8f3ec97245.png
#   inflating: drive/My Drive/Colab Notebooks/Kaggle/Dataset/test/b3db392f5ee8.png
#   inflating: drive/My Drive/Colab Notebooks/Kaggle/Dataset/test/c71728f9535b.png
#   inflating: drive/My Drive/Colab Notebooks/Kaggle/Dataset/test/c7c003cdaaba.png
#   inflating: drive/My Drive/Colab Notebooks/Kaggle/Dataset/test/67b614d32bcc.png
#   inflating: drive/My Drive/Colab Notebooks/Kaggle/Dataset/test/e982c6b5b726.png
#   inflating: drive/My Drive/Colab Notebooks/Kaggle/Dataset/test/e2fdc91493f4.png
#   inflating: drive/My Drive/Colab Notebooks/Kaggle/Dataset/test/1d1539c0fb03.png
# ...

# %%
# !find drive/My\ Drive/Colab\ Notebooks/Kaggle/Dataset/test -type f | wc -l
# Out:
# 1928
